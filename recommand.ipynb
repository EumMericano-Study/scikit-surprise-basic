# %%
# !pip3 install IPython 
from IPython.display import Image  #
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: IPython in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (8.2.0)
# Requirement already satisfied: decorator in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (0.18.1)
# Requirement already satisfied: traitlets>=5 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (2.12.0)
# Requirement already satisfied: setuptools>=18.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from IPython) (49.2.1)
# Requirement already satisfied: stack-data in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: backcall in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (0.2.0)
# Requirement already satisfied: appnope in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (0.1.3)
# Requirement already satisfied: matplotlib-inline in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from IPython) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: asttokens in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: executing in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: six in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from asttokens->stack-data->IPython) (1.15.0)

# %% [markdown]
# # 추천 시스템 (Recommender Systems)
#
# * 추천 시스템은 크게 두가지로 구분 가능
#   * 컨텐츠 기반 필터링 (content-based filtering)
#   * 협업 필터링 (collaborative filtering)
# * 두가지를 조합한 hybrid 방식도 가능
# * 컨텐츠 기반 필터링은 지금까지 사용자의 이전 행동과 명시적 피드백을 통해 사용자가 좋아하는 것과 유사한 항목을 추천
# * 협업 필터링은 사용자와 항목간의 유사성을 동시에 사용해 추천

# %% [markdown]
# ## Surprise
#
# * 추천 시스템 개발을 위한 라이브러리
# * 다양한 모델과 데이터 제공
# * scikit-learn과 유사한 사용 방법

# %%
# !pip3 install numpy
# !pip3 install scikit-surprise
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (1.22.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-surprise in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.11.2 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from scikit-surprise) (1.22.3)
# Requirement already satisfied: scipy>=1.0.0 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from scikit-surprise) (1.8.0)
# Requirement already satisfied: joblib>=0.11 in /Users/eumericano/Library/Python/3.8/lib/python/site-packages (from scikit-surprise) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-surprise) (1.15.0)

# %% [markdown]
# ## 간단한 Surprise 실습

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate

# %% [markdown]
# 간단한 Surprise 실습

# %%
data= Dataset.load_builtin('ml-100k', prompt=False)
data.raw_ratings[:10]
# Out:
# [('196', '242', 3.0, '881250949'),
#  ('186', '302', 3.0, '891717742'),
#  ('22', '377', 1.0, '878887116'),
#  ('244', '51', 2.0, '880606923'),
#  ('166', '346', 1.0, '886397596'),
#  ('298', '474', 4.0, '884182806'),
#  ('115', '265', 2.0, '881171488'),
#  ('253', '465', 5.0, '891628467'),
#  ('305', '451', 3.0, '886324817'),
#  ('6', '86', 3.0, '883603013')]

# %%
model = SVD()

# %% [markdown]
# SVD, 특이값 분해

# %%
Image('image/svd.png')

# %%
cross_validate(model, data, measures=['rmse', 'mae'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9353  0.9364  0.9258  0.9432  0.9378  0.9357  0.0056
# MAE (testset)     0.7384  0.7392  0.7315  0.7456  0.7378  0.7385  0.0045
# Fit time          2.50    2.51    2.36    2.40    2.33    2.42    0.07
# Test time         0.06    0.05    0.09    0.05    0.05    0.06    0.01
# {'test_rmse': array([0.93531749, 0.93638816, 0.92582979, 0.9432283 , 0.93777433]),
#  'test_mae': array([0.73841911, 0.73917992, 0.73150443, 0.7456077 , 0.73777242]),
#  'fit_time': (2.496751308441162,
#   2.510183811187744,
#   2.358112096786499,
#   2.403891086578369,
#   2.3342278003692627),
#  'test_time': (0.061141014099121094,
#   0.05405092239379883,
#   0.09025001525878906,
#   0.05335807800292969,
#   0.05353188514709473)}
